# %%
# llama2 depth first summaries
# prompt: You are a text summarizer. your task is to generate a concise summary of the provided debate
# within the strict 90-word limit without making assumptions or utilizing bullet points. If you don't follow 
# the word limit, you will be punished.
# Even in this case, output summary is 406 word summary

# llama2 depth first summaries - shorten - llama2_summarization_dfs_resend.pynb
# available in llm_output_updated --> depth_first
# But even this method add assumptional statements and dont stick to information provided.

# %%
# Large language models couldn't produce word count limited text.
# so, if the final summaries of llama2 or gpt4 are more than the given word count
# we send it back into the model to produce text within the given limit.

# %%
pip install openai==0.28
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai

# %%
def chat(Messages):
    response = openai.ChatCompletion.create(
    model="ollama/llama2:70b",
    messages=Messages
    )
    return response.choices[0].message.content

# %%
# llama2 divide and conquer summaries / depth first- shorten
import os

def shorten_llama2_summaries(input_folder, output_folder):
    count = 0
    for filename in os.listdir(input_folder):
         if filename.endswith(".txt"):
            print(filename)
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename)

            # read the content of the file
            with open(input_file_path, 'r', encoding='utf-8') as file:
                file_content = file.read()
                
            word_count = len(file_content.split())
            if word_count > 90:
                print('word count exceeded')
                count = count+1
                # method_1
                #new_messages = [
                        #{"role": "assistant", "content": file_content},
                        #{"role": "user", "content": "The summary that you provided exceeds the specified word limit. Please provide summary of the debate in 90 words without any opening statements. Ensure no assumptions are made and adhere strictly to the provided information." }
                    #] 
                # method_1 results are totally inappropiate
                # method_2
                new_messages = [
                        {"role": "system", "content": "As a text summarizer, you were tasked with summarizing a debate in 90 words. However, the summary you supplied exceeds the prescribed word limit. Please condense the provided summary to 90 words without making assumptions and strictly adhering to the given information."},
                        {"role": "user", "content": file_content }
                    ] 
                
                #print('Messages', Messages)
                final_summary = chat(new_messages)
                
                # write the concatenated result to a text file in the output folder  
                with open(output_file_path, 'w', encoding="utf8") as output_file:
                    output_file.write(final_summary)
            else:
                # within the limit, write the same content
                with open(output_file_path, 'w', encoding="utf8") as output_file:
                    output_file.write(file_content) 
    print('count',count)

# %%
# input_folder_path - final summary produced by divide conquer/depth first approach
# output_folder_path - shortened summary

input_folder_path = "C:/Users/Nila/Documents/Main Scripts_25.12.2023/Jupyter Notebooks/complete testing/llm_output/LLAMA2/depth_first"
output_folder_path = "C:/Users/Nila/Documents/Main Scripts_25.12.2023/Jupyter Notebooks/complete testing/llm_output_updated/LLAMA2/depth_first_redo"

shorten_llama2_summaries(input_folder_path, output_folder_path)
# Out:
# 3d-printer-and-guns-should-blueprints-of-3d-printed-weapons-be-prohibited-17593.txt
# word count exceeded
# a-bar-of-soap-is-better-than-a-bottle-of-shower-gel-21205.txt
# word count exceeded
# a-childs-primary-carer-should-receive-a-wage-until-the-child-enters-primary-school-or-some-other-form-of-care-17763.txt
# word count exceeded
# a-flat-asset-tax-is-all-the-tax-we-should-ever-pay-16974.txt
# word count exceeded
# a-free-press-is-necessary-to-democracy-8559.txt
# word count exceeded
# a-permanent-venue-for-the-olympic-games-1335.txt
# word count exceeded
# addressing-psychosocial-factors-is-essential-to-reducing-or-preventing-school-shootings-11784.txt
# word count exceeded
# agile-certifications-do-not-advance-agile-thinking-14073.txt
# word count exceeded
# air-traffic-control-atc-should-not-be-privatized-12138.txt
# word count exceeded
# alex-jones-has-a-negative-impact-on-society-19233.txt
# word count exceeded
# ...

# %%
## json - shorten

# %%
# llama2 divide and conquer summaries / depth first- shorten
import os

def shorten_llama2_summaries(input_folder, output_folder):
    count = 0
    for filename in os.listdir(input_folder):
         if filename.endswith(".txt"):
            print(filename)
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename)

            # read the content of the file
            with open(input_file_path, 'r', encoding='utf-8') as file:
                file_content = file.read()
                
            word_count = len(file_content.split())
            if word_count > 90:
                print('word count exceeded')
                count = count+1
                # method_1
                #new_messages = [
                        #{"role": "assistant", "content": file_content},
                        #{"role": "user", "content": "The summary that you provided exceeds the specified word limit. Please provide summary of the debate in 90 words without any opening statements. Ensure no assumptions are made and adhere strictly to the provided information." }
                    #] 
                # method_1 results are totally inappropiate
                # method_2
                new_messages = [
                        {"role": "system", "content": "As a graph summarizer, you were tasked with summarizing a debate in 90 words without graph information such as node id, edges. However, the summary you supplied exceeds the prescribed word limit and also include graph information . Please condense the provided debate to 90 words without making assumptions and strictly adhering to the given information. Also make sure summary doesn't have node labels/id"},
                        {"role": "user", "content": file_content }
                    ] 
                
                #print('Messages', Messages)
                final_summary = chat(new_messages)
                
                # write the concatenated result to a text file in the output folder  
                with open(output_file_path, 'w', encoding="utf8") as output_file:
                    output_file.write(final_summary)
            else:
                # within the limit, write the same content
                with open(output_file_path, 'w', encoding="utf8") as output_file:
                    output_file.write(file_content) 
    print('count',count)

# %%
# input_folder_path - final summary produced by json approach
# output_folder_path - shortened summary

input_folder_path = "C:/Users/Nila/Documents/Main Scripts_25.12.2023/Jupyter Notebooks/complete testing/llm_output_updated/LLAMA2/json_resend"
output_folder_path = "C:/Users/Nila/Documents/Main Scripts_25.12.2023/Jupyter Notebooks/complete testing/llm_output_updated/LLAMA2/json_shorten"

shorten_llama2_summaries(input_folder_path, output_folder_path)
# Out:
# 3d-printer-and-guns-should-blueprints-of-3d-printed-weapons-be-prohibited-17593.txt
# word count exceeded
# a-bar-of-soap-is-better-than-a-bottle-of-shower-gel-21205.txt
# word count exceeded
# a-childs-primary-carer-should-receive-a-wage-until-the-child-enters-primary-school-or-some-other-form-of-care-17763.txt
# word count exceeded
# a-flat-asset-tax-is-all-the-tax-we-should-ever-pay-16974.txt
# word count exceeded
# a-free-press-is-necessary-to-democracy-8559.txt
# word count exceeded
# a-permanent-venue-for-the-olympic-games-1335.txt
# word count exceeded
# addressing-psychosocial-factors-is-essential-to-reducing-or-preventing-school-shootings-11784.txt
# word count exceeded
# agile-certifications-do-not-advance-agile-thinking-14073.txt
# word count exceeded
# air-traffic-control-atc-should-not-be-privatized-12138.txt
# word count exceeded
# alex-jones-has-a-negative-impact-on-society-19233.txt
# word count exceeded
# ...

# %%
# llama2 - divide and conquer - shorten
# out of 55 summaries, 30 summaries are out of word limit.
# Final summary is condensed within the word limit - Main information are not lost. 
# available in folder llm_output_updated\LLAMA2\divide_conquer
# avg word length before shortening - 113
# average word length after shortening - 90.34

# llama2 - depth first - shorten redo
# out of 55 summaries, 52 summaries are out of word limit.
# first method in llama2_summarization_dfs_resend.pynb made lot of assumptions in the given summary
# using the above approach, Final summary is condensed within the word limit - Main information are not lost. 
# available in folder llm_output_updated\LLAMA2\depth_first_redo
# avg word length before shortening - 219
# average word length after shortening - 94

# llama2 - Json - shorten
# 1 set availble in JSON_resend
